# %% [markdown]
# # **1. Import libary and load dataset**

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/glass.csv')

# %%
min_values = data.min()
max_values = data.max()

print("Minimum values:")
print(min_values)

print("\nMaximum values:")
print(max_values)
# Out:
# Minimum values:
# Id_number         1.00000
# RI                1.51115
# Na               10.73000
# Mg                0.00000
# AI                0.29000
# Si               69.81000
# K                 0.00000
# Ca                5.43000
# Ba                0.00000
# Fe                0.00000
# Type_of_glass     1.00000
# dtype: float64
#
# Maximum values:
# Id_number        214.00000
# RI                 1.53393
# Na                17.38000
# Mg                 4.49000
# AI                 3.50000
# Si                75.41000
# K                  6.21000
# Ca                16.19000
# Ba                 3.15000
# Fe                 0.51000
# Type_of_glass      7.00000
# dtype: float64

# %% [markdown]
# # **2. Display Top 5 rows of the Dataset**

# %%
data.head()
# Out:
#    Id_number       RI     Na    Mg    AI     Si     K    Ca   Ba   Fe  \
# 0          1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Type_of_glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# # **3. Display Last 5 rows of the Dataset**

# %%
data.tail()
# Out:
#      Id_number       RI     Na   Mg    AI     Si     K    Ca    Ba   Fe  \
# 209        210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type_of_glass
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7

# %% [markdown]
# # **4. Get Information about the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id_number      214 non-null    int64
#  1   RI             214 non-null    float64
#  2   Na             214 non-null    float64
#  3   Mg             214 non-null    float64
#  4   AI             214 non-null    float64
#  5   Si             214 non-null    float64
#  6   K              214 non-null    float64
#  7   Ca             214 non-null    float64
#  8   Ba             214 non-null    float64
#  9   Fe             214 non-null    float64
#  10  Type_of_glass  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %% [markdown]
# # **5. Check null values in the dataset**

# %%
data.isnull().sum()
# Out:
# Id_number        0
# RI               0
# Na               0
# Mg               0
# AI               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type_of_glass    0
# dtype: int64

# %% [markdown]
# # **6. Get Overall statistics about the dataset**

# %%
data.describe()
# Out:
#         Id_number          RI          Na          Mg          AI          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Type_of_glass
# count  214.000000  214.000000  214.000000  214.000000     214.000000
# mean     0.497056    8.956963    0.175047    0.057009       2.780374
# ...

# %%
data.head()
# Out:
#    Id_number       RI     Na    Mg    AI     Si     K    Ca   Ba   Fe  \
# 0          1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Type_of_glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
data.tail()
# Out:
#      Id_number       RI     Na   Mg    AI     Si     K    Ca    Ba   Fe  \
# 209        210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type_of_glass
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7

# %% [markdown]
# # **8. Data Normalization**

# %%
my_working_dataset = data.copy()

# %%
#Data normalisation is applied for four attributes to make the data more consistent
my_working_dataset['RI']=(my_working_dataset['RI']-my_working_dataset['RI'].min())/(my_working_dataset['RI'].max()-my_working_dataset['RI'].min())
my_working_dataset['Na']=(my_working_dataset['Na']-my_working_dataset['Na'].min())/(my_working_dataset['Na'].max()-my_working_dataset['Na'].min())
my_working_dataset['Mg']=(my_working_dataset['Mg']-my_working_dataset['Mg'].min())/(my_working_dataset['Mg'].max()-my_working_dataset['Mg'].min())
my_working_dataset['AI']=(my_working_dataset['AI']-my_working_dataset['AI'].min())/(my_working_dataset['AI'].max()-my_working_dataset['AI'].min())
my_working_dataset['Si']=(my_working_dataset['Si']-my_working_dataset['Si'].min())/(my_working_dataset['Si'].max()-my_working_dataset['Si'].min())
my_working_dataset['K']=(my_working_dataset['K']-my_working_dataset['K'].min())/(my_working_dataset['K'].max()-my_working_dataset['K'].min())
my_working_dataset['Ca']=(my_working_dataset['Ca']-my_working_dataset['Ca'].min())/(my_working_dataset['Ca'].max()-my_working_dataset['Ca'].min())
my_working_dataset['Ba']=(my_working_dataset['Ba']-my_working_dataset['Ba'].min())/(my_working_dataset['Ba'].max()-my_working_dataset['Ba'].min())
my_working_dataset['Fe']=(my_working_dataset['Fe']-my_working_dataset['Fe'].min())/(my_working_dataset['Fe'].max()-my_working_dataset['Fe'].min())
print(my_working_dataset.head(100))
print(my_working_dataset.describe())
# Out:
#     Id_number        RI        Na        Mg        AI        Si         K  \
# 0           1  0.432836  0.437594  1.000000  0.252336  0.351786  0.009662
# 1           2  0.283582  0.475188  0.801782  0.333333  0.521429  0.077295
# 2           3  0.220808  0.421053  0.790646  0.389408  0.567857  0.062802
# 3           4  0.285777  0.372932  0.821826  0.311526  0.500000  0.091787
# 4           5  0.275241  0.381955  0.806236  0.295950  0.583929  0.088567
# ..        ...       ...       ...       ...       ...       ...       ...
# 95         96  0.327041  0.395489  0.763920  0.355140  0.437500  0.082126
# 96         97  0.318701  0.344361  0.806236  0.239875  0.451786  0.103060
# 97         98  0.275680  0.221053  0.723831  0.271028  0.667857  0.099839
# 98         99  0.251975  0.291729  0.641425  0.442368  0.607143  0.117552
# 99        100  0.305531  0.335338  0.659243  0.355140  0.555357  0.096618
#
#           Ca        Ba        Fe  Type_of_glass
# ...

# %% [markdown]
# # **9. Data Visualization**

# %% [markdown]
# ## **9.1. Representing feature values**

# %%
#Only attributes with numeric values on a continuous scale are selected for value visualisation
data_for_visualisation = my_working_dataset[["RI","Na","Mg","AI","Si","K","Ca","Ba","Fe"]]
#Representing values
data_for_visualisation.plot(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# The analysis of above graph allows us to making the following conclusions:
#
# 1. When the Magnesium (Mg) content is greater than 0.8, the values of Aluminum (Al), Calcium (Ca), and Potassium (K) tend to be lower (values < 0.4).
#
# 2. When the Magnesium (Mg) content is around 0.6, the values of Sodium (Na), Aluminum (Al), and Silicon (Si) are also around that same range — showing a merging behavior.
#
# 3. When the Magnesium (Mg) content is less than 0.4, the values of Potassium (K) and Barium (Ba) tend to increase sharply (values > 0.6), indicating a shift in composition.
#
# 4. In general, the features Na, Al, and Si tend to change together — showing similar trends and variations across the dataset.
#
# 5. Potassium (K) and Barium (Ba) show sharp spikes, likely indicating distinct subgroups or rare glass types.

# %% [markdown]
# ## **9.2. Histograms**

# %%
#Only attributes with numeric values on a continuous scale are selected for value visualisation
data_for_visualisation = my_working_dataset[["RI","Na","Mg","AI","Si","K","Ca","Ba","Fe","Type_of_glass"]]
#Displaying histograms
data_for_visualisation.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'RI'}>, <Axes: title={'center': 'Na'}>,
#         <Axes: title={'center': 'Mg'}>],
#        [<Axes: title={'center': 'AI'}>, <Axes: title={'center': 'Si'}>,
#         <Axes: title={'center': 'K'}>],
#        [<Axes: title={'center': 'Ca'}>, <Axes: title={'center': 'Ba'}>,
#         <Axes: title={'center': 'Fe'}>],
#        [<Axes: title={'center': 'Type_of_glass'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# The analysis of above histogram allows us to making the following conclusions:
#
# 1. The distribution of glass types is not balanced becuase some classes (like types 2 and 1) appear more frequently but others (like types 3, 5, and 6) are under-represented in the dataset. Mainly 4, is not even represented in dataset.
#
# 2. Several chemical elements such as Barium (Ba), Iron (Fe), and Potassium (K) have skewed distributions, with most samples concentrated in lower value ranges, indicating rare occurrences of high concentrations.
#
# 3. The Magnesium (Mg), Sodium (Na) and Refractive Index (RI) features show more peaked distributions, suggesting that many glass samples share similar values for these features.
#
# 4. Elements like Aluminum (AI), Silicon (Si) and Calcium (Ca) are more normally distributed, indicating more balanced variation across the dataset.

# %% [markdown]
# ## **9.3. Scatter plots**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating a pairplot
my_pairplot = sns.pairplot(my_working_dataset,hue='Type_of_glass',palette="muted",height=3,vars=['RI', 'Na', 'Mg', 'AI', 'Si', 'K', 'Ca', 'Ba', 'Fe'], kind='scatter')
#Extra space to display the title correctly
plt.subplots_adjust(top=0.9)
#Giving a title of the pairplot
my_pairplot.fig.suptitle('Feature pairplot of Glass Dataset',fontsize=25,color='b',alpha=0.6)
# Out:
# Text(0.5, 0.98, 'Feature pairplot of Glass Dataset')

# %% [markdown]
# We analyse features relationships based on type of glass.
#
# 1. The scatter plots suggest that such pairs of features provide reasonably good class separation in this dataset:
# * "Magnesium (Mg)" and " Refractive Index (RI)"
# * "Magnesium (Mg)" and "Calcium (Ca)"
# * "Refractive Index (RI)" and "Potassium (K)"
# which can be used in a classification task.
#
# 2. However, the following pairs of features do not provide good class separation in this dataset:
#
# * However, feature pairs such as ,
#
# 1. "Aluminium (AI) and Refractive index (RI): red objects partially merged with blue objects and other objects are partially seperable.
# 2. "Silicon (Si)" and "Iron (Fe)" , "Sodium( Na)" and "Iron (Fe)" , "Magnesium( Mg)" and "Iron (Fe), "Calcium(Ca)" and "Iron (Fe)" are also paritially well seperable.
# 3. "Calcium (Ca)" and "Silicon (Si)" red, blue, purple and some green data objects are mixed together. Same like this, there are some combination which are not well seperable.

# %% [markdown]
# ## **9.4. Feature Correlation**

# %%
#A correlation matrix is created, showing the correlation coefficient for the numeric features
my_correlation_matrix=data_for_visualisation.corr(method='pearson')
plt.figure(figsize=(20,10))
sns.heatmap(my_correlation_matrix,vmax=1,square=True,annot=True,cmap='cubehelix')
# Out:
# <Axes: >

# %% [markdown]
# The correlation matrix analysis shows that:
#
# 1. There is a weak negative correlation between the features "RI" and "Ba".
#
# 2. The feature "Ba" has an average positive correlation with the feature "AI".
#
# 3. The feature "Mg" has an average negative correlation with the features "Ba" and "AI".
#
# 4. There is a high positive correlation between the features "Ca" and "RI"
#
# Thus, for the features Ca and RI, one can anticipate a multicollinearity problem that may complicate the interpretation of the linear regression results, so that it would not be desirable to include one fo those features in the further analysis.

# %% [markdown]
# # **10. K-means Algorithm**

# %%
#loading the necessay libraries
from sklearn.cluster import KMeans
from sklearn import metrics
#a dataset is selected for the clustering task, including 3 attributes from the normalized dataset
clustering_dataset = my_working_dataset[['Mg','Ca','K','Na']]
#Creating a list of silhouette coefficient values
Silhouette_coefficient = []
#a loop with 6 iterations is implemented (6 different values for the number of clusters)
# 1 cluster is not considered in this case because it is not meaningful to calculate the silhouette coefficient for 1 cluster
for i in range(2,6):
   #Creation of a K-means clustering model where the number of clusters (n_clusters) is equal to the loop iteration number (2, 3..)
   kmeans_model = KMeans(n_clusters = i, init = "k-means++")
   #training of K-means model
   kmeans_model.fit(clustering_dataset)
   #Calculating the Silhouette coeffcient
   Silhouette_coefficient.append(metrics.silhouette_score(clustering_dataset, kmeans_model.labels_))
print(Silhouette_coefficient)
#representing the results visually
plt.figure(figsize=(4,4))
plt.plot(range(2,6), Silhouette_coefficient)
plt.xlabel('Cluster number')
plt.ylabel('Silhouette coefficient')
plt.show()
# Out:
# [np.float64(0.7015082784446044), np.float64(0.5258735297879378), np.float64(0.5783211572198768), np.float64(0.5620643804462376)]

# %%
#an additonal libary is added to represent the results of clustering
import matplotlib.pyplot as plt
#a K-means model with 2 clusters is created and trained using the dataset with 3 features
kmeans_model = KMeans(n_clusters=2, init = "k-means++").fit(clustering_dataset)
#acquiring cluster centers
centroids = kmeans_model.cluster_centers_
#make predictions for cluster membership of data objects
y_pred = kmeans_model.predict(clustering_dataset)
plt.subplot(2,2,1)                            # A 2 x 2 matrix of images is created, index starting with 1 in the top left corner
plt.scatter(clustering_dataset['Mg'], clustering_dataset['Ca'], s = 10, c = y_pred)
plt.scatter(centroids[0,0], centroids[0,1], s = 100, c = 'g', marker = 's')
plt.scatter(centroids[1,0], centroids[1,1], s = 100, c = 'g', marker = 's')
plt.subplot(2,2,2)                            # Create the next image in the matrix with index 2
plt.scatter(clustering_dataset['Ca'], clustering_dataset['K'], s = 10, c = y_pred)
plt.scatter(centroids[0,0], centroids[0,1], s = 100, c = 'g', marker = 's')
plt.scatter(centroids[1,0], centroids[1,1], s = 100, c = 'g', marker = 's')
plt.subplot(2,2,3)                            # Create the next image in the matrix with index 3
plt.scatter(clustering_dataset['K'], clustering_dataset['Na'], s = 10, c = y_pred)
plt.scatter(centroids[0,0], centroids[0,1], s = 100, c = 'g', marker = 's')
plt.scatter(centroids[1,0], centroids[1,1], s = 100, c = 'g', marker = 's')
plt.subplot(2,2,4)
plt.scatter(clustering_dataset['Na'], clustering_dataset['Mg'], s = 10, c = y_pred)
plt.scatter(centroids[0,0], centroids[0,1], s = 100, c = 'g', marker = 's')
plt.scatter(centroids[1,0], centroids[1,1], s = 100, c = 'g', marker = 's')
plt.show()

# %%
#an additonal libary is added to represent the results of clustering
import matplotlib.pyplot as plt
#a K-means model with 2 clusters is created and trained using the dataset with 3 features
kmeans_model = KMeans(n_clusters=2, init = "k-means++").fit(clustering_dataset)
#acquiring cluster centers
centroids = kmeans_model.cluster_centers_
#make predictions for cluster membership of data objects
y_pred = kmeans_model.predict(clustering_dataset)
plt.subplot(2,2,1)
plt.scatter(clustering_dataset['Mg'], clustering_dataset['K'], s = 10, c = y_pred)
plt.scatter(centroids[0,0], centroids[0,1], s = 100, c = 'g', marker = 's')
plt.scatter(centroids[1,0], centroids[1,1], s = 100, c = 'g', marker = 's')
plt.show()

# %% [markdown]
# # **11. Heirarchical Clustering**

# %%
#an additional library is needed to use the algorithm
from sklearn.cluster import AgglomerativeClustering
#creating an algorithm model, using a datset with 3 features
clustering = AgglomerativeClustering().fit(clustering_dataset)

# %%
#adding a library to represent a dendrogramm
import scipy.cluster.hierarchy as shc
#creating a dendrogramm using a linkage method "single"
plt.figure(figsize =(14, 8))
plt.title('Dendrogramm')
Dendrogram = shc.dendrogram((shc.linkage(clustering_dataset, method ='single')))

# %% [markdown]
# # **12. Artifical Neuron Network**

# %%
#importing a library for splitting the dataset into test and training dataset
from sklearn.model_selection import train_test_split
#saving the target values of the data objects, i.e. "penguin species", in a separate variable
targets = my_working_dataset['Type_of_glass']
#specifying the proportion of data objects that will form the training dataset (70%)
training_proportion = 0.75
#splitting the dataset into test and training sets using a random 70:30 split
X_train, X_test, y_train, y_test = train_test_split(clustering_dataset, targets, test_size=1.0 - training_proportion, random_state=42)

# %%
#importing a library to work with artificial neural networks
from sklearn.neural_network import MLPClassifier
#building an artificial neural network model with 2 layers, each containing 100 neurons
#The following parameters are set: the maximum number of training iterations is 50, the activation function is adam,
#the weight matching method is stochastic gradient descent, the output of training iterations
my_ann_model = MLPClassifier(hidden_layer_sizes=(100,100), max_iter=500, activation = 'logistic', solver='adam', learning_rate_init = 0.1, verbose = 1)
my_ann_model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 1.97927955
# Iteration 2, loss = 4.13228177
# Iteration 3, loss = 5.25434797
# Iteration 4, loss = 2.83648879
# Iteration 5, loss = 2.65912695
# Iteration 6, loss = 3.35664436
# Iteration 7, loss = 3.51621276
# Iteration 8, loss = 3.20438460
# Iteration 9, loss = 2.40594868
# Iteration 10, loss = 1.71491141
# Iteration 11, loss = 1.86961772
# Iteration 12, loss = 2.27929359
# Iteration 13, loss = 2.23348234
# Iteration 14, loss = 1.93530044
# Iteration 15, loss = 1.95171417
# Iteration 16, loss = 2.00251975
# Iteration 17, loss = 1.81516018
# Iteration 18, loss = 1.80590053
# Iteration 19, loss = 1.78262070
# Iteration 20, loss = 1.71050468
# Iteration 21, loss = 1.70539285
# Iteration 22, loss = 1.71535647
# Iteration 23, loss = 1.73101546
# Iteration 24, loss = 1.72085715
# Iteration 25, loss = 1.58965241
# Iteration 26, loss = 1.51721421
# Iteration 27, loss = 1.61593424
# Iteration 28, loss = 1.68931538
# Iteration 29, loss = 1.63521949
# ...

# %%
#importing libraries for acquiring and representing performance metrics
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import pylab as pltb
#we use the trained model with a test set to obtain predictions
y_predictions = my_ann_model.predict(X_test)
#displaying metrics
print(classification_report(y_test,y_predictions, zero_division=0))
#creating a confusion matrix
my_confusion_matrix = confusion_matrix(y_test, y_predictions)
#displaying the confusion matrix
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['Type_of_glass'].unique());
ax.yaxis.set_ticklabels(data['Type_of_glass'].unique());
# Out:
#               precision    recall  f1-score   support
#
#            1       0.26      1.00      0.41        14
#            2       0.00      0.00      0.00        21
#            3       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00         4
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         8
#
#     accuracy                           0.26        54
#    macro avg       0.04      0.17      0.07        54
# weighted avg       0.07      0.26      0.11        54

# %% [markdown]
# The confusion matrix shows that 23 data objects were misclassified, so the overall accuracy of the network is quite low at 35%.

# %% [markdown]
# ## **Model 2 , 2 layer 15 neurons**

# %%
#building an artificial neural network model with 1 layer and 5 neurons in it
#The following parameters are set: the maximum number of training iterations is 50, the activation function is logistic,
#the weight matching method is stochastic gradient descent, the output of training iterations
my_ann_model_2 = MLPClassifier(hidden_layer_sizes=(15, 15), max_iter=500, activation = 'relu', solver='adam', learning_rate_init = 0.1, verbose = 0)
my_ann_model_2.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(15, 15), learning_rate_init=0.1, max_iter=500,
#               verbose=0)

# %%
#we use the trained model with a test set to obtain predictions
y_predictions_2 = my_ann_model_2.predict(X_test)
#displaying metrics
print(classification_report(y_test,y_predictions_2, zero_division=0))
#creating a confusion matrix
my_confusion_matrix = confusion_matrix(y_test, y_predictions_2)
#displaying the confusion matrix
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['Type_of_glass'].unique());
ax.yaxis.set_ticklabels(data['Type_of_glass'].unique());
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.93      0.70        14
#            2       0.71      0.57      0.63        21
#            3       0.00      0.00      0.00         4
#            5       1.00      0.25      0.40         4
#            6       0.25      0.33      0.29         3
#            7       0.78      0.88      0.82         8
#
#     accuracy                           0.63        54
#    macro avg       0.55      0.49      0.47        54
# weighted avg       0.62      0.63      0.60        54

# %% [markdown]
# # **13. kNN Algorithm**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as pltb
import seaborn as sns

# Scale your features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create KNN model with same hyperparameters as in Orange
from sklearn.neighbors import KNeighborsClassifier
KNN_MODEL = KNeighborsClassifier(n_neighbors=3, metric='euclidean', weights='distance')

# %%
# Train the model
KNN_MODEL.fit(X_train_scaled, y_train)

# Predict
y_predictions_knn = KNN_MODEL.predict(X_test_scaled)

# Classification report
print(classification_report(y_test, y_predictions_knn, zero_division=0))

# Confusion matrix
my_confusion_matrix = confusion_matrix(y_test, y_predictions_knn)
fig, ax = pltb.subplots(figsize=(7, 4))
sns.heatmap(my_confusion_matrix, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted class labels')
ax.set_ylabel('True class labels')
ax.set_title('Confusion matrix')
ax.xaxis.set_ticklabels(data['Type_of_glass'].unique())
ax.yaxis.set_ticklabels(data['Type_of_glass'].unique())
# Out:
#               precision    recall  f1-score   support
#
#            1       0.59      0.71      0.65        14
#            2       0.94      0.76      0.84        21
#            3       0.20      0.25      0.22         4
#            5       1.00      1.00      1.00         4
#            6       0.67      0.67      0.67         3
#            7       0.88      0.88      0.88         8
#
#     accuracy                           0.74        54
#    macro avg       0.71      0.71      0.71        54
# weighted avg       0.77      0.74      0.75        54
# [Text(0, 0.5, '1'),
#  Text(0, 1.5, '2'),
#  Text(0, 2.5, '3'),
#  Text(0, 3.5, '5'),
#  Text(0, 4.5, '6'),
#  Text(0, 5.5, '7')]

# %% [markdown]
# # **14. Random Forest**

# %%
# Importing necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Create the Random Forest model with specified parameters
RF_MODEL = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=42)

# Train the model
RF_MODEL.fit(X_train, y_train)

# Make predictions on the test set
y_predictions_rf = RF_MODEL.predict(X_test)

# Print classification report
print(classification_report(y_test, y_predictions_rf, zero_division=0))

# Generate and plot the confusion matrix
conf_matrix_rf = confusion_matrix(y_test, y_predictions_rf)
fig, ax = plt.subplots(figsize=(7, 4))
sns.heatmap(conf_matrix_rf, annot=True, fmt='g', ax=ax)
ax.set_xlabel('Predicted class labels')
ax.set_ylabel('True class labels')
ax.set_title('Random Forest - Confusion Matrix')
ax.xaxis.set_ticklabels(data['Type_of_glass'].unique())
ax.yaxis.set_ticklabels(data['Type_of_glass'].unique())
plt.tight_layout()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.71      0.86      0.77        14
#            2       0.89      0.76      0.82        21
#            3       0.00      0.00      0.00         4
#            5       0.57      1.00      0.73         4
#            6       0.50      0.33      0.40         3
#            7       0.78      0.88      0.82         8
#
#     accuracy                           0.74        54
#    macro avg       0.57      0.64      0.59        54
# weighted avg       0.71      0.74      0.72        54
